# %%
import pandas as pd

data = pd.read_csv('./Datasets/Salary/employee_attrition_test.csv')
data
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %%
data.isnull()
# Out:
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     True           False      False       False              True
# 1    False           False      False       False             False
# 2    False           False      False       False             False
# 3    False           False      False       False             False
# 4    False           False      False       False              True
# ..     ...             ...        ...         ...               ...
# 436  False           False      False       False             False
# 437  False           False      False       False             False
# 438   True           False      False       False             False
# 439  False           False      False       False             False
# 440   True           False      False       False             False
#
#      Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0        False           False          False           False
# ...

# %%
data.notnull()
# Out:
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    False            True       True        True             False
# 1     True            True       True        True              True
# 2     True            True       True        True              True
# 3     True            True       True        True              True
# 4     True            True       True        True             False
# ..     ...             ...        ...         ...               ...
# 436   True            True       True        True              True
# 437   True            True       True        True              True
# 438  False            True       True        True              True
# 439   True            True       True        True              True
# 440  False            True       True        True              True
#
#      Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0         True            True           True            True
# ...

# %%
data.dropna() # axis = 0       -> '0' which removes row (its default),
              #                   '1' removes columns. 
              # inplace = true -> updates the existing data.
              # how = any      -> 'any' removes whole row/column if any value is nan (its default), 
              #                   'all' removes whole row/column if all value in row/column is nan.
              # thresh = 12    -> threshold, by defualt value is '1'.
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 5    34.0      Travel_Rarely      204.0                   Sales
# 8    45.0         Non-Travel     1052.0                   Sales
# ..    ...                ...        ...                     ...
# 434  50.0      Travel_Rarely      410.0                   Sales
# 435  49.0      Travel_Rarely      470.0  Research & Development
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 439  39.0      Travel_Rarely     1383.0         Human Resources
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 1                13.0          2           Medical              1
# ...

# %%
data.fillna(121)
# Out:
#        Age     BusinessTravel  DailyRate              Department  \
# 0    121.0      Travel_Rarely      866.0                   Sales
# 1     53.0      Travel_Rarely     1084.0  Research & Development
# 2     24.0      Travel_Rarely      240.0         Human Resources
# 3     45.0      Travel_Rarely     1339.0  Research & Development
# 4     36.0      Travel_Rarely     1396.0  Research & Development
# ..     ...                ...        ...                     ...
# 436   33.0  Travel_Frequently      430.0                   Sales
# 437   27.0         Non-Travel      210.0                   Sales
# 438  121.0      Travel_Rarely     1157.0  Research & Development
# 439   39.0      Travel_Rarely     1383.0         Human Resources
# 440  121.0      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0               121.0          3          Medical              1
# ...

# %%
# # removes columns in which row has nan value.
# data.dropna(axis=1) 

# # updates the existing data.
# data.dropna(inplace = true)       

# # removes whole row if all value in row is nan.
# data.dropna(how='all')

# # removes whole row if 4 values in row is nan.
# data.dropna(thresh='4')

# %%
data.fillna({'Age':30, 'DistanceFromHome':40})
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0    30.0      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438  30.0      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440  30.0      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                40.0          3          Medical              1
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 436    False
# 437    False
# 438    False
# 439    False
# 440    False
# Length: 441, dtype: bool

# %%
data.duplicated(['Age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 436     True
# 437     True
# 438     True
# 439     True
# 440     True
# Length: 441, dtype: bool

# %%
data.drop_duplicates()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %%
data.drop_duplicates(['Age'])
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# 5    34.0      Travel_Rarely      204.0                   Sales
# 7    39.0      Travel_Rarely     1431.0  Research & Development
# 10   47.0      Travel_Rarely     1454.0                   Sales
# 11   43.0      Travel_Rarely      531.0                   Sales
# 12   44.0      Travel_Rarely      625.0  Research & Development
# 13   40.0      Travel_Rarely     1171.0  Research & Development
# 14   22.0      Travel_Rarely      581.0  Research & Development
# 15   30.0  Travel_Frequently     1312.0  Research & Development
# 16   29.0  Travel_Frequently      461.0  Research & Development
# ...

# %%
test = map(lambda x: x.lower(), data['Department'])
list(test)
# Out:
# ['sales',
#  'research & development',
#  'human resources',
#  'research & development',
#  'research & development',
#  'sales',
#  'research & development',
#  'research & development',
#  'sales',
#  'research & development',
#  'sales',
#  'sales',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'sales',
#  'sales',
#  'sales',
#  'sales',
#  'research & development',
#  'sales',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'sales',
#  'sales',
#  'research & development',
#  'research & development',
#  'research & development',
#  'research & development',
#  'sales',
#  'sales',
# ...

# %%
data['Department'].map(lambda x: x.lower())
# Out:
# 0                       sales
# 1      research & development
# 2             human resources
# 3      research & development
# 4      research & development
#                 ...
# 436                     sales
# 437                     sales
# 438    research & development
# 439           human resources
# 440    research & development
# Name: Department, Length: 441, dtype: object

# %%
data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
data['EducationField'].unique()
# Out:
# array(['Medical', 'Human Resources', 'Life Sciences', 'Technical Degree',
#        'Marketing', 'Other'], dtype=object)

# %%
tab = {
    'Product': {1: 'Apple', 2: 'Onion', 3: 'Pineapple', 4: 'Cabbage'},
    'Price': {1: 10, 2: 7, 3: 8, 4: 12},
    'Quantity': {1: 23, 2: 52, 3: 63, 4: 14}
}
df = pd.DataFrame(tab)
df
# Out:
#      Product  Price  Quantity
# 1      Apple     10        23
# 2      Onion      7        52
# 3  Pineapple      8        63
# 4    Cabbage     12        14

# %%
product_to_category = {
    'apple': 'Fruit',
    'pineapple': 'Fruit',
    'onion': 'Vegetable',
    'cabbage': 'Vegetable',
}
lowercased = df['Product'].str.lower()
df['Category'] = lowercased.map(product_to_category)
df
# Out:
#      Product  Price  Quantity   Category
# 1      Apple     10        23      Fruit
# 2      Onion      7        52  Vegetable
# 3  Pineapple      8        63      Fruit
# 4    Cabbage     12        14  Vegetable
