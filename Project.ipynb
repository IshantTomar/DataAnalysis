# %% [markdown]
# # Importing CSV File

# %%
import pandas as pd
import numpy as np
salary_data = pd.read_csv('D:/Coding/Python/Projects/DataAnalysis/Datasets/Salary/employee_attrition_test.csv')
salary_data
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %% [markdown]
# # DataFrame

# %%
type(salary_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h3>Print starting values</h3>

# %%
salary_data.head(10)
# Out:
#     Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0   NaN  Travel_Rarely      866.0                   Sales               NaN
# 1  53.0  Travel_Rarely     1084.0  Research & Development              13.0
# 2  24.0  Travel_Rarely      240.0         Human Resources              22.0
# 3  45.0  Travel_Rarely     1339.0  Research & Development               7.0
# 4  36.0  Travel_Rarely     1396.0  Research & Development               NaN
# 5  34.0  Travel_Rarely      204.0                   Sales              14.0
# 6   NaN  Travel_Rarely      144.0  Research & Development              22.0
# 7  39.0  Travel_Rarely     1431.0  Research & Development               1.0
# 8  45.0     Non-Travel     1052.0                   Sales               6.0
# 9   NaN  Travel_Rarely     1229.0  Research & Development               8.0
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          3           Medical              1            1469
# ...

# %% [markdown]
# <h3>Print Bottom values</h3>

# %%
salary_data.tail(10)
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 431  54.0      Travel_Rarely      376.0  Research & Development
# 432  37.0         Non-Travel     1413.0  Research & Development
# 433  33.0         Non-Travel        NaN                   Sales
# 434  50.0      Travel_Rarely      410.0                   Sales
# 435  49.0      Travel_Rarely      470.0  Research & Development
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 431              19.0          4           Medical              1
# 432               NaN          2  Technical Degree              1
# ...

# %% [markdown]
# <h3>Print a specific column</h3>

# %%
salary_data['MonthlyIncome']
# Out:
# 0      8463
# 1      4450
# 2      1555
# 3      9724
# 4      5914
#        ...
# 436    4373
# 437    6349
# 438    3464
# 439    5204
# 440    2074
# Name: MonthlyIncome, Length: 441, dtype: int64

# %% [markdown]
# <h3>Change all values of a specific column</h3>

# %%
column_change = salary_data
column_change['MonthlyIncome'] = 127.98
column_change['MonthlyIncome']
# Out:
# 0      127.98
# 1      127.98
# 2      127.98
# 3      127.98
# 4      127.98
#         ...
# 436    127.98
# 437    127.98
# 438    127.98
# 439    127.98
# 440    127.98
# Name: MonthlyIncome, Length: 441, dtype: float64

# %% [markdown]
# <h3>Assigning some values to specific index</h3>

# %%
row_values = salary_data
# Adding a new column and assigning values to it.
values = pd.Series([10,50,21.5,30], index = [1,4,5,6])
row_values['Stress'] = values
row_values.head(10)
# Out:
#     Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 0   NaN  Travel_Rarely      866.0                   Sales               NaN
# 1  53.0  Travel_Rarely     1084.0  Research & Development              13.0
# 2  24.0  Travel_Rarely      240.0         Human Resources              22.0
# 3  45.0  Travel_Rarely     1339.0  Research & Development               7.0
# 4  36.0  Travel_Rarely     1396.0  Research & Development               NaN
# 5  34.0  Travel_Rarely      204.0                   Sales              14.0
# 6   NaN  Travel_Rarely      144.0  Research & Development              22.0
# 7  39.0  Travel_Rarely     1431.0  Research & Development               1.0
# 8  45.0     Non-Travel     1052.0                   Sales               6.0
# 9   NaN  Travel_Rarely     1229.0  Research & Development               8.0
#
#    Education    EducationField  EmployeeCount  EmployeeNumber  \
# 0          3           Medical              1            1469
# ...

# %% [markdown]
# <h3>Removing a column</h3>
